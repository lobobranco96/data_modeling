# %%
import duckdb

# %%
"https://dbdiagram.io/d"


"""CREATE TABLE dim_localidade AS
SELECT DISTINCT
    customer_city AS cidade,
    customer_state AS estado
FROM clientes

UNION

SELECT DISTINCT
    seller_city AS cidade,
    seller_state AS estado
FROM vendedores;

CREATE TABLE dim_clientes AS
SELECT DISTINCT
    c.customer_id,
    c.customer_unique_id,
    l.localidade_id
FROM clientes c
JOIN dim_localidade l ON c.customer_city = l.cidade AND c.customer_state = l.estado;


CREATE TABLE dim_vendedores AS
SELECT DISTINCT
    v.seller_id,
    v.seller_zip_code_prefix,
    l.localidade_id
FROM vendedores v
JOIN dim_localidade l ON v.seller_city = l.cidade AND v.seller_state = l.estado;


""""
